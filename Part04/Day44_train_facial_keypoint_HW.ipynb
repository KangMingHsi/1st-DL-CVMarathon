# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0203 22:50:10.725995 13220 deprecation_wrapper.py:119] From c:\users\seankang\anaconda3\envs\python37\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0203 22:50:10.726994 13220 deprecation_wrapper.py:119] From c:\users\seankang\anaconda3\envs\python37\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0203 22:50:10.727995 13220 deprecation_wrapper.py:119] From c:\users\seankang\anaconda3\envs\python37\lib\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0203 22:50:11.360135 13220 deprecation_wrapper.py:119] From c:\users\seankang\anaconda3\envs\python37\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# W0203 22:50:37.337149 13220 deprecation_wrapper.py:119] From c:\users\seankang\anaconda3\envs\python37\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0203 22:50:37.347159 13220 deprecation_wrapper.py:119] From c:\users\seankang\anaconda3\envs\python37\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0203 22:50:37.391200 13220 deprecation.py:506] From c:\users\seankang\anaconda3\envs\python37\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0203 22:50:37.424228 13220 deprecation_wrapper.py:119] From c:\users\seankang\anaconda3\envs\python37\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 0.0073 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00237, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00002: val_loss improved from 0.00237 to 0.00205, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00205 to 0.00188, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00188
# Epoch 5/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00188 to 0.00181, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss did not improve from 0.00181
# Epoch 7/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 9.8096e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00181 to 0.00167, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 8.1529e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00167 to 0.00149, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 6.8045e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00149 to 0.00131, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 6.1057e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00131 to 0.00118, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 5.6105e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00118 to 0.00112, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 5.1995e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00112 to 0.00110, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 4.8732e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00110 to 0.00102, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 4.4058e-04 - val_loss: 9.4191e-04
#
# Epoch 00014: val_loss improved from 0.00102 to 0.00094, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 4.0930e-04 - val_loss: 9.3839e-04
#
# Epoch 00015: val_loss improved from 0.00094 to 0.00094, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 3.9413e-04 - val_loss: 9.1034e-04
#
# Epoch 00016: val_loss improved from 0.00094 to 0.00091, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 3.7886e-04 - val_loss: 8.5391e-04
#
# Epoch 00017: val_loss improved from 0.00091 to 0.00085, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 3.6936e-04 - val_loss: 8.5443e-04
#
# Epoch 00018: val_loss did not improve from 0.00085
# Epoch 19/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 3.4929e-04 - val_loss: 8.4206e-04
#
# Epoch 00019: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 3.3253e-04 - val_loss: 8.1252e-04
#
# Epoch 00020: val_loss improved from 0.00084 to 0.00081, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 3.2447e-04 - val_loss: 8.7872e-04
#
# Epoch 00021: val_loss did not improve from 0.00081
# Epoch 22/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 3.1569e-04 - val_loss: 7.9958e-04
#
# Epoch 00022: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 3.0367e-04 - val_loss: 7.8698e-04
#
# Epoch 00023: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 2.9043e-04 - val_loss: 8.0220e-04
#
# Epoch 00024: val_loss did not improve from 0.00079
# Epoch 25/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 2.8877e-04 - val_loss: 7.6691e-04
#
# Epoch 00025: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 2.7130e-04 - val_loss: 7.5885e-04
#
# Epoch 00026: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 2.6880e-04 - val_loss: 7.6041e-04
#
# Epoch 00027: val_loss did not improve from 0.00076
# Epoch 28/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 2.5697e-04 - val_loss: 7.9120e-04
#
# Epoch 00028: val_loss did not improve from 0.00076
# Epoch 29/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 2.5524e-04 - val_loss: 7.9381e-04
#
# Epoch 00029: val_loss did not improve from 0.00076
# Epoch 30/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 2.4815e-04 - val_loss: 7.6060e-04
#
# Epoch 00030: val_loss did not improve from 0.00076
# Epoch 31/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 2.4317e-04 - val_loss: 7.6570e-04
#
# Epoch 00031: val_loss did not improve from 0.00076
# Epoch 32/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 2.3976e-04 - val_loss: 7.5113e-04
#
# Epoch 00032: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 2.4630e-04 - val_loss: 7.6137e-04
#
# Epoch 00033: val_loss did not improve from 0.00075
# Epoch 34/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.3461e-04 - val_loss: 7.5456e-04
#
# Epoch 00034: val_loss did not improve from 0.00075
# Epoch 35/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.2261e-04 - val_loss: 7.3267e-04
#
# Epoch 00035: val_loss improved from 0.00075 to 0.00073, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 2.2817e-04 - val_loss: 7.0824e-04
#
# Epoch 00036: val_loss improved from 0.00073 to 0.00071, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 2.1696e-04 - val_loss: 7.4983e-04
#
# Epoch 00037: val_loss did not improve from 0.00071
# Epoch 38/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 2.1576e-04 - val_loss: 7.5778e-04
#
# Epoch 00038: val_loss did not improve from 0.00071
# Epoch 39/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 2.1810e-04 - val_loss: 7.5069e-04
#
# Epoch 00039: val_loss did not improve from 0.00071
# Epoch 40/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 2.1173e-04 - val_loss: 7.1771e-04
#
# Epoch 00040: val_loss did not improve from 0.00071
# Epoch 41/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 2.1384e-04 - val_loss: 7.5086e-04
#
# Epoch 00041: val_loss did not improve from 0.00071
# Epoch 42/150
# 1712/1712 [==============================] - 0s 261us/step - loss: 2.0269e-04 - val_loss: 7.6011e-04
#
# Epoch 00042: val_loss did not improve from 0.00071
# Epoch 43/150
# 1712/1712 [==============================] - 0s 258us/step - loss: 1.9842e-04 - val_loss: 7.2663e-04
#
# Epoch 00043: val_loss did not improve from 0.00071
# Epoch 44/150
# 1712/1712 [==============================] - 0s 257us/step - loss: 1.9565e-04 - val_loss: 7.6847e-04
#
# Epoch 00044: val_loss did not improve from 0.00071
# Epoch 45/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.9570e-04 - val_loss: 7.2626e-04
#
# Epoch 00045: val_loss did not improve from 0.00071
# Epoch 46/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.8754e-04 - val_loss: 7.3177e-04
#
# Epoch 00046: val_loss did not improve from 0.00071
# Epoch 47/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.8292e-04 - val_loss: 7.4799e-04
#
# Epoch 00047: val_loss did not improve from 0.00071
# Epoch 48/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.9113e-04 - val_loss: 7.3728e-04
#
# Epoch 00048: val_loss did not improve from 0.00071
# Epoch 49/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 1.8691e-04 - val_loss: 7.2043e-04
#
# Epoch 00049: val_loss did not improve from 0.00071
# Epoch 50/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.8449e-04 - val_loss: 7.0101e-04
#
# Epoch 00050: val_loss improved from 0.00071 to 0.00070, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 1.7821e-04 - val_loss: 7.1587e-04
#
# Epoch 00051: val_loss did not improve from 0.00070
# Epoch 52/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 1.7880e-04 - val_loss: 7.2517e-04
#
# Epoch 00052: val_loss did not improve from 0.00070
# Epoch 53/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 1.7318e-04 - val_loss: 7.1303e-04
#
# Epoch 00053: val_loss did not improve from 0.00070
# Epoch 54/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.7087e-04 - val_loss: 7.3156e-04
#
# Epoch 00054: val_loss did not improve from 0.00070
# Epoch 55/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.6833e-04 - val_loss: 7.0651e-04
#
# Epoch 00055: val_loss did not improve from 0.00070
# Epoch 56/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.6676e-04 - val_loss: 7.0309e-04
#
# Epoch 00056: val_loss did not improve from 0.00070
# Epoch 57/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.6595e-04 - val_loss: 7.3759e-04
#
# Epoch 00057: val_loss did not improve from 0.00070
# Epoch 58/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.6054e-04 - val_loss: 7.2775e-04
#
# Epoch 00058: val_loss did not improve from 0.00070
# Epoch 59/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 1.5971e-04 - val_loss: 7.0398e-04
#
# Epoch 00059: val_loss did not improve from 0.00070
# Epoch 60/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.6190e-04 - val_loss: 7.3721e-04
#
# Epoch 00060: val_loss did not improve from 0.00070
# Epoch 61/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.5772e-04 - val_loss: 6.9760e-04
#
# Epoch 00061: val_loss improved from 0.00070 to 0.00070, saving model to best_weights.h5
# Epoch 62/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.5510e-04 - val_loss: 7.1912e-04
#
# Epoch 00062: val_loss did not improve from 0.00070
# Epoch 63/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 1.5336e-04 - val_loss: 6.9420e-04
#
# Epoch 00063: val_loss improved from 0.00070 to 0.00069, saving model to best_weights.h5
# Epoch 64/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.5037e-04 - val_loss: 6.8822e-04
#
# Epoch 00064: val_loss improved from 0.00069 to 0.00069, saving model to best_weights.h5
# Epoch 65/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.4938e-04 - val_loss: 6.8412e-04
#
# Epoch 00065: val_loss improved from 0.00069 to 0.00068, saving model to best_weights.h5
# Epoch 66/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.5055e-04 - val_loss: 6.9094e-04
#
# Epoch 00066: val_loss did not improve from 0.00068
# Epoch 67/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 1.4679e-04 - val_loss: 6.9011e-04
#
# Epoch 00067: val_loss did not improve from 0.00068
# Epoch 68/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.4601e-04 - val_loss: 6.7253e-04
#
# Epoch 00068: val_loss improved from 0.00068 to 0.00067, saving model to best_weights.h5
# Epoch 69/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 1.4407e-04 - val_loss: 7.1917e-04
#
# Epoch 00069: val_loss did not improve from 0.00067
# Epoch 70/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.4419e-04 - val_loss: 7.2186e-04
#
# Epoch 00070: val_loss did not improve from 0.00067
# Epoch 71/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.4311e-04 - val_loss: 7.2772e-04
#
# Epoch 00071: val_loss did not improve from 0.00067
# Epoch 72/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.4059e-04 - val_loss: 7.1339e-04
#
# Epoch 00072: val_loss did not improve from 0.00067
# Epoch 73/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 1.3801e-04 - val_loss: 7.0680e-04
#
# Epoch 00073: val_loss did not improve from 0.00067
# Epoch 74/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.4081e-04 - val_loss: 6.9041e-04
#
# Epoch 00074: val_loss did not improve from 0.00067
# Epoch 75/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.3846e-04 - val_loss: 7.1112e-04
#
# Epoch 00075: val_loss did not improve from 0.00067
# Epoch 76/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.3916e-04 - val_loss: 7.1387e-04
#
# Epoch 00076: val_loss did not improve from 0.00067
# Epoch 77/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.3569e-04 - val_loss: 7.2228e-04
#
# Epoch 00077: val_loss did not improve from 0.00067
# Epoch 78/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.3222e-04 - val_loss: 7.3647e-04
#
# Epoch 00078: val_loss did not improve from 0.00067
# Epoch 79/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.3432e-04 - val_loss: 7.1249e-04
#
# Epoch 00079: val_loss did not improve from 0.00067
# Epoch 80/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.3345e-04 - val_loss: 7.0548e-04
#
# Epoch 00080: val_loss did not improve from 0.00067
# Epoch 81/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.3589e-04 - val_loss: 6.9040e-04
#
# Epoch 00081: val_loss did not improve from 0.00067
# Epoch 82/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.3472e-04 - val_loss: 7.3115e-04
#
# Epoch 00082: val_loss did not improve from 0.00067
# Epoch 83/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.2938e-04 - val_loss: 7.2699e-04
#
# Epoch 00083: val_loss did not improve from 0.00067
# Epoch 84/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.2632e-04 - val_loss: 7.3997e-04
#
# Epoch 00084: val_loss did not improve from 0.00067
# Epoch 85/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.2451e-04 - val_loss: 7.1432e-04
#
# Epoch 00085: val_loss did not improve from 0.00067
# Epoch 86/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.2327e-04 - val_loss: 7.0948e-04
#
# Epoch 00086: val_loss did not improve from 0.00067
# Epoch 87/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.2807e-04 - val_loss: 7.2904e-04
#
# Epoch 00087: val_loss did not improve from 0.00067
# Epoch 88/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.2115e-04 - val_loss: 6.9603e-04
#
# Epoch 00088: val_loss did not improve from 0.00067
# Epoch 89/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.2289e-04 - val_loss: 7.0819e-04
#
# Epoch 00089: val_loss did not improve from 0.00067
# Epoch 90/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.2132e-04 - val_loss: 7.2198e-04
#
# Epoch 00090: val_loss did not improve from 0.00067
# Epoch 91/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.2067e-04 - val_loss: 6.9898e-04
#
# Epoch 00091: val_loss did not improve from 0.00067
# Epoch 92/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.1861e-04 - val_loss: 7.1070e-04
#
# Epoch 00092: val_loss did not improve from 0.00067
# Epoch 93/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 1.1821e-04 - val_loss: 6.9996e-04
#
# Epoch 00093: val_loss did not improve from 0.00067
# Epoch 94/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.1610e-04 - val_loss: 7.1700e-04
#
# Epoch 00094: val_loss did not improve from 0.00067
# Epoch 95/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.2192e-04 - val_loss: 6.8220e-04
#
# Epoch 00095: val_loss did not improve from 0.00067
# Epoch 96/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 1.1933e-04 - val_loss: 7.5799e-04
#
# Epoch 00096: val_loss did not improve from 0.00067
# Epoch 97/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.1672e-04 - val_loss: 7.0432e-04
#
# Epoch 00097: val_loss did not improve from 0.00067
# Epoch 98/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.1489e-04 - val_loss: 7.1072e-04
#
# Epoch 00098: val_loss did not improve from 0.00067
# Epoch 99/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.1262e-04 - val_loss: 7.0658e-04
#
# Epoch 00099: val_loss did not improve from 0.00067
# Epoch 100/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 1.1098e-04 - val_loss: 7.3609e-04
#
# Epoch 00100: val_loss did not improve from 0.00067
# Epoch 101/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.1363e-04 - val_loss: 7.2045e-04
#
# Epoch 00101: val_loss did not improve from 0.00067
# Epoch 102/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.1237e-04 - val_loss: 7.2651e-04
#
# Epoch 00102: val_loss did not improve from 0.00067
# Epoch 103/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 1.1273e-04 - val_loss: 6.9881e-04
#
# Epoch 00103: val_loss did not improve from 0.00067
# Epoch 104/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.0981e-04 - val_loss: 7.2667e-04
#
# Epoch 00104: val_loss did not improve from 0.00067
# Epoch 105/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.0820e-04 - val_loss: 6.8627e-04
#
# Epoch 00105: val_loss did not improve from 0.00067
# Epoch 106/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.0808e-04 - val_loss: 7.0532e-04
#
# Epoch 00106: val_loss did not improve from 0.00067
# Epoch 107/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0898e-04 - val_loss: 7.1565e-04
#
# Epoch 00107: val_loss did not improve from 0.00067
# Epoch 108/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.0492e-04 - val_loss: 7.2848e-04
#
# Epoch 00108: val_loss did not improve from 0.00067
# Epoch 109/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.0884e-04 - val_loss: 7.3464e-04
#
# Epoch 00109: val_loss did not improve from 0.00067
# Epoch 110/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.0832e-04 - val_loss: 7.3000e-04
#
# Epoch 00110: val_loss did not improve from 0.00067
# Epoch 111/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.0354e-04 - val_loss: 7.0651e-04
#
# Epoch 00111: val_loss did not improve from 0.00067
# Epoch 112/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.0730e-04 - val_loss: 7.1999e-04
#
# Epoch 00112: val_loss did not improve from 0.00067
# Epoch 113/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0255e-04 - val_loss: 7.2017e-04
#
# Epoch 00113: val_loss did not improve from 0.00067
# Epoch 114/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0474e-04 - val_loss: 6.8951e-04
#
# Epoch 00114: val_loss did not improve from 0.00067
# Epoch 115/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0288e-04 - val_loss: 7.0999e-04
#
# Epoch 00115: val_loss did not improve from 0.00067
# Epoch 116/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.9671e-05 - val_loss: 7.0055e-04
#
# Epoch 00116: val_loss did not improve from 0.00067
# Epoch 117/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.0102e-04 - val_loss: 7.0710e-04
#
# Epoch 00117: val_loss did not improve from 0.00067
# Epoch 118/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.0002e-04 - val_loss: 6.8551e-04
#
# Epoch 00118: val_loss did not improve from 0.00067
# Epoch 119/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 9.8728e-05 - val_loss: 7.0325e-04
#
# Epoch 00119: val_loss did not improve from 0.00067
# Epoch 120/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.0128e-04 - val_loss: 7.0278e-04
#
# Epoch 00120: val_loss did not improve from 0.00067
# Epoch 121/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0121e-04 - val_loss: 6.7312e-04
#
# Epoch 00121: val_loss did not improve from 0.00067
# Epoch 122/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.7532e-05 - val_loss: 7.0775e-04
#
# Epoch 00122: val_loss did not improve from 0.00067
# Epoch 123/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 9.4597e-05 - val_loss: 6.8945e-04
#
# Epoch 00123: val_loss did not improve from 0.00067
# Epoch 124/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.0076e-04 - val_loss: 7.2005e-04
#
# Epoch 00124: val_loss did not improve from 0.00067
# Epoch 125/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.7467e-05 - val_loss: 7.3318e-04
#
# Epoch 00125: val_loss did not improve from 0.00067
# Epoch 126/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 9.5074e-05 - val_loss: 7.1270e-04
#
# Epoch 00126: val_loss did not improve from 0.00067
# Epoch 127/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 9.3199e-05 - val_loss: 7.2330e-04
#
# Epoch 00127: val_loss did not improve from 0.00067
# Epoch 128/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.4279e-05 - val_loss: 6.9959e-04
#
# Epoch 00128: val_loss did not improve from 0.00067
# Epoch 129/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 9.3059e-05 - val_loss: 7.4131e-04
#
# Epoch 00129: val_loss did not improve from 0.00067
# Epoch 130/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 9.1848e-05 - val_loss: 7.1474e-04
#
# Epoch 00130: val_loss did not improve from 0.00067
# Epoch 131/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 9.1387e-05 - val_loss: 7.0129e-04
#
# Epoch 00131: val_loss did not improve from 0.00067
# Epoch 132/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 9.1859e-05 - val_loss: 7.4536e-04
#
# Epoch 00132: val_loss did not improve from 0.00067
# Epoch 133/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 8.8690e-05 - val_loss: 7.0605e-04
#
# Epoch 00133: val_loss did not improve from 0.00067
# Epoch 134/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 9.0974e-05 - val_loss: 7.1035e-04
#
# Epoch 00134: val_loss did not improve from 0.00067
# Epoch 135/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.0414e-05 - val_loss: 7.5245e-04
#
# Epoch 00135: val_loss did not improve from 0.00067
# Epoch 136/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 9.1258e-05 - val_loss: 7.6823e-04
#
# Epoch 00136: val_loss did not improve from 0.00067
# Epoch 137/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 9.2048e-05 - val_loss: 7.1240e-04
#
# Epoch 00137: val_loss did not improve from 0.00067
# Epoch 138/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 8.8882e-05 - val_loss: 7.1212e-04
#
# Epoch 00138: val_loss did not improve from 0.00067
# Epoch 139/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 8.7561e-05 - val_loss: 7.3870e-04
#
# Epoch 00139: val_loss did not improve from 0.00067
# Epoch 140/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 8.5809e-05 - val_loss: 7.2778e-04
#
# Epoch 00140: val_loss did not improve from 0.00067
# Epoch 141/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 8.6025e-05 - val_loss: 7.1354e-04
#
# Epoch 00141: val_loss did not improve from 0.00067
# Epoch 142/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 8.4673e-05 - val_loss: 7.6023e-04
#
# Epoch 00142: val_loss did not improve from 0.00067
# Epoch 143/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 8.3215e-05 - val_loss: 7.2787e-04
#
# Epoch 00143: val_loss did not improve from 0.00067
# Epoch 144/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 8.3977e-05 - val_loss: 7.4517e-04
#
# Epoch 00144: val_loss did not improve from 0.00067
# Epoch 145/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 8.6691e-05 - val_loss: 7.4961e-04
#
# Epoch 00145: val_loss did not improve from 0.00067
# Epoch 146/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 8.4755e-05 - val_loss: 7.0844e-04
#
# Epoch 00146: val_loss did not improve from 0.00067
# Epoch 147/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 8.5385e-05 - val_loss: 7.2330e-04
#
# Epoch 00147: val_loss did not improve from 0.00067
# Epoch 148/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 8.4418e-05 - val_loss: 7.5600e-04
#
# Epoch 00148: val_loss did not improve from 0.00067
# Epoch 149/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 8.4884e-05 - val_loss: 7.4189e-04
#
# Epoch 00149: val_loss did not improve from 0.00067
# Epoch 150/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 8.3799e-05 - val_loss: 6.8952e-04
#
# Epoch 00150: val_loss did not improve from 0.00067

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, point_tests = load_data(dirname = 'test.csv')
print("圖像資料:", imgs_test.shape, "\n關鍵點資料:", point_tests.shape)
# Out:
# 圖像資料: (1783, 96, 96)
# 關鍵點資料: (1783, 1)

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 2,shear_range = 0.2,zoom_range = 0.2,horizontal_flip = True)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, nb_epoch = 20, callbacks=[checkpoint, hist], shuffle=True, validation_data=(train_X, points_train))
# Out:
# Epoch 1/20
#  7/66 [==>...........................] - ETA: 1s - loss: 5.1670e-04
# c:\users\seankang\anaconda3\envs\python37\lib\site-packages\ipykernel_launcher.py:8: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#
# c:\users\seankang\anaconda3\envs\python37\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=66, callbacks=[<keras.ca..., shuffle=True, validation_data=(array([[[..., epochs=20)`
# 66/66 [==============================] - 2s 27ms/step - loss: 5.1954e-04 - val_loss: 5.6361e-04
#
# Epoch 00001: val_loss improved from inf to 0.00056, saving model to best_weights.h5
# Epoch 2/20
# 66/66 [==============================] - 1s 23ms/step - loss: 5.2786e-04 - val_loss: 5.3797e-04
#
# Epoch 00002: val_loss improved from 0.00056 to 0.00054, saving model to best_weights.h5
# Epoch 3/20
# 66/66 [==============================] - 1s 22ms/step - loss: 5.1559e-04 - val_loss: 5.4502e-04
#
# Epoch 00003: val_loss did not improve from 0.00054
# Epoch 4/20
# 66/66 [==============================] - 1s 22ms/step - loss: 5.1993e-04 - val_loss: 5.0263e-04
#
# Epoch 00004: val_loss improved from 0.00054 to 0.00050, saving model to best_weights.h5
# Epoch 5/20
# 66/66 [==============================] - 1s 22ms/step - loss: 5.0887e-04 - val_loss: 5.0713e-04
#
# Epoch 00005: val_loss did not improve from 0.00050
# Epoch 6/20
# 66/66 [==============================] - 1s 22ms/step - loss: 5.1233e-04 - val_loss: 5.1210e-04
#
# Epoch 00006: val_loss did not improve from 0.00050
# Epoch 7/20
# 66/66 [==============================] - 2s 23ms/step - loss: 5.0479e-04 - val_loss: 5.9203e-04
#
# Epoch 00007: val_loss did not improve from 0.00050
# Epoch 8/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.7696e-04 - val_loss: 5.4452e-04
#
# Epoch 00008: val_loss did not improve from 0.00050
# Epoch 9/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.9617e-04 - val_loss: 5.3050e-04
#
# Epoch 00009: val_loss did not improve from 0.00050
# Epoch 10/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.8134e-04 - val_loss: 5.4962e-04
#
# Epoch 00010: val_loss did not improve from 0.00050
# Epoch 11/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.5741e-04 - val_loss: 5.7170e-04
#
# Epoch 00011: val_loss did not improve from 0.00050
# Epoch 12/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.6694e-04 - val_loss: 5.9199e-04
#
# Epoch 00012: val_loss did not improve from 0.00050
# Epoch 13/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.6177e-04 - val_loss: 5.4767e-04
#
# Epoch 00013: val_loss did not improve from 0.00050
# Epoch 14/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.5095e-04 - val_loss: 5.0820e-04
#
# Epoch 00014: val_loss did not improve from 0.00050
# Epoch 15/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.5569e-04 - val_loss: 5.1569e-04
#
# Epoch 00015: val_loss did not improve from 0.00050
# Epoch 16/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.6831e-04 - val_loss: 4.9018e-04
#
# Epoch 00016: val_loss improved from 0.00050 to 0.00049, saving model to best_weights.h5
# Epoch 17/20
# 66/66 [==============================] - 1s 23ms/step - loss: 4.4808e-04 - val_loss: 5.7116e-04
#
# Epoch 00017: val_loss did not improve from 0.00049
# Epoch 18/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.2903e-04 - val_loss: 5.3714e-04
#
# Epoch 00018: val_loss did not improve from 0.00049
# Epoch 19/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.4846e-04 - val_loss: 5.7857e-04
#
# Epoch 00019: val_loss did not improve from 0.00049
# Epoch 20/20
# 66/66 [==============================] - 1s 22ms/step - loss: 4.5533e-04 - val_loss: 5.3917e-04
#
# Epoch 00020: val_loss did not improve from 0.00049

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(model_with_augment.history['loss'], color='b', label='Training Loss')
plt.plot(model_with_augment.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-e2644d91a146> in <module>()
#       2 plt.title('Optimizer : Adam', fontsize=10)
#       3 plt.ylabel('Loss', fontsize=16)
# ----> 4 plt.plot(model_with_augment.history['loss'], color='b', label='Training Loss')
#       5 plt.plot(model_with_augment.history['val_loss'], color='r', label='Validation Loss')
#       6 plt.legend(loc='upper right')
#
# TypeError: 'History' object is not subscriptable

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %%
point_tests[0]
# Out:
# array([-0.48958334], dtype=float32)
